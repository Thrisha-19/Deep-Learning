# %% [markdown]
# <a href="https://colab.research.google.com/github/Thrisha-19/Deep-Learning/blob/main/chatbot2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import json
import nltk
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, GlobalMaxPooling1D, Flatten
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt

# %%
# %%writefile content.json
# {"intents":
#   [
#     {
#       "tag": "greeting",
#       "input": ["Hello","Hi","Nice to meet you","Hi this is the pirate's organisation","any pirates here","hi there","Hey","Hey there"],
#       "responses":[
#           "Hi Welcome to the world's largest pirate organisation - The Tech Chaos",
#           "Hey yo, do you need any help?",
#           "Welcome How may I help you?",
#           "Aloha!",
#           "Hi random person, What do you want?",
#           "Hello my friend, How can I help you?",
#           "Ha, Glad you showed up, How are ya?"
#       ]
#     },
#     {
#       "tag":"goodbye",
#       "input":["Thank you","Thanks","Thanks for the info","Bye","bye bro","adios","Okay bye","goodbye","see you later","i will catch you later"],
#       "responses":[
#            "Okay, Bye",
#            "Have a nice day",
#            "Adios",
#            "Goodbye",
#            "See ya later",
#            "Nice come again",
#            "Okay, have a nice day",
#            "Take care"
#       ]
#     },
#     {
#       "tag":"howami ",
#       "input":["how are you","i am fine, how are you?","are you fine?","how are things going?","everything going on okay?","how's everything?"],
#       "responses":[
#            "Yeah, am fine",
#            "Everything's going on well",
#            "Doing good. Thanks you are the best",
#            "Yeah fine, nothing much going on in my life",
#            "Things are great",
#            "I am great, wanna join the organisation?",
#            "Everything's great",
#            "I am doing good. Life's boring. Need to go on an adventure"
#       ]
#     },
#     {
#       "tag":"whoareyou",
#       "input":["who are you ?","what are you ?","what is your name ?","are you a chatbot ?","what can I call you ?","your name ?","are you a bot?"],
#       "responses":[
#         "I am The Great Pirate Bot, you can call me Going Merry",
#         "i am Going Merry and you could ask me questions about about our organisation",
#         "Going Merry at your service",
#         "My name is Going Merry and yes, I am the G.O.A.T",
#         "You can call me TechBot and I am here to help you",
#         "My name is Going Merry and I am here to answer your questions regardung our organisation. Go ahead and shoot"
#       ]
#     },
#     {
#       "tag":"whereareyou",
#       "input":["where are you from ?","which country are you from ?","where do you live ?","where do you live ?","which place do you live ?"],
#       "responses":[
#         "I live in the East Blue",
#         "I am setting sail to the grand line",
#         "I live in East Blue. Pretty sure you wouldn't have haeard about that",
#         "East Blue. That's where I live"
#       ]
#     },
#     {
#     "tag":"join",
#     "input":["how to get recruited ?","how to join ?","how do i get recruited ?","how to join strawhats ?","how do I join strawhats ?"],
#     "responses":[
#       "you need to contact the nearest straw hats centre once you  have completed the pre-requisites",
#       "contact the closest straw hat centre from your location",
#       "well. There are some pre-requisites and after you complete them, find the straw hat centres"
#      ]
#    },
#    {
#     "tag":"whereisthecentre",
#     "input":["where is the straw hat centre located ?","location of the straw hat centre","straw hat centre location","where can I find the straw hat centre ?"],
#     "responses":[
#       "That's upto you. Use your skills",
#       "They are present all over the city you live in. Find them on your own. I can't give any more information",
#       "There are a lot of straw hat centres in the city you are in. Find them."
#     ]
#   },
#   {
#     "tag":"prerequisites",
#     "input":["what are the job requirements ?","what are the pre requisites ?","what are the pre-requisites ?","tell me about the pre-requisites ?"],
#     "responses":[
#       "you gotta master the art of swordfight or master cooking and become a furious cook or you have to be the best navigator in the entire world",
#       "swordsman, a medical reindeer , taekwondo cook, master navigator,simple minded monkey,highly intelligent strategist,god usop."
#     ]
#   }
#  ]
# }
# Out:
# Writing content.json

# %% [markdown]
# IMPORTING THE DATASET

# %%
import json
with open('content.json') as content:
  data1 = json.load(content)

# %% [markdown]
# GETTING ALL THE DATA TO LISTS

# %%
tags = []
inputs = []
responses = {}
for intent in data1['intents']:
  responses[intent['tag']] = intent['responses']
  for lines in intent['input']:
    inputs.append(lines)
    tags.append(intent['tag'])

# %% [markdown]
# CONVERTING TO DATAFRAME

# %%
data = pd.DataFrame({"inputs":inputs,
                     "tags":tags})

# %%
data
# Out:
#                                      inputs              tags
# 0                                     Hello          greeting
# 1                                        Hi          greeting
# 2                          Nice to meet you          greeting
# 3      Hi this is the pirate's organisation          greeting
# 4                          any pirates here          greeting
# 5                                  hi there          greeting
# 6                                       Hey          greeting
# 7                                 Hey there          greeting
# 8                                 Thank you           goodbye
# 9                                    Thanks           goodbye
# 10                      Thanks for the info           goodbye
# 11                                      Bye           goodbye
# 12                                  bye bro           goodbye
# 13                                    adios           goodbye
# 14                                 Okay bye           goodbye
# 15                                  goodbye           goodbye
# 16                            see you later           goodbye
# 17                   i will catch you later           goodbye
# 18                              how are you           howami
# 19                  i am fine, how are you?           howami
# 20                            are you fine?           howami
# 21                    how are things going?           howami
# 22                everything going on okay?           howami
# 23                        how's everything?           howami
# 24                            who are you ?         whoareyou
# 25                           what are you ?         whoareyou
# 26                      what is your name ?         whoareyou
# 27                      are you a chatbot ?         whoareyou
# 28                    what can I call you ?         whoareyou
# 29                              your name ?         whoareyou
# 30                           are you a bot?         whoareyou
# 31                     where are you from ?       whereareyou
# 32             which country are you from ?       whereareyou
# 33                      where do you live ?       whereareyou
# 34                      where do you live ?       whereareyou
# 35                which place do you live ?       whereareyou
# 36                   how to get recruited ?              join
# 37                            how to join ?              join
# 38                 how do i get recruited ?              join
# 39                  how to join strawhats ?              join
# 40                how do I join strawhats ?              join
# 41  where is the straw hat centre located ?  whereisthecentre
# 42         location of the straw hat centre  whereisthecentre
# 43                straw hat centre location  whereisthecentre
# 44  where can I find the straw hat centre ?  whereisthecentre
# 45          what are the job requirements ?     prerequisites
# 46            what are the pre requisites ?     prerequisites
# 47            what are the pre-requisites ?     prerequisites
# 48       tell me about the pre-requisites ?     prerequisites

# %% [markdown]
# PRE PROCESSING

# %%
#removing punctuations
import string
data['inputs'] = data['inputs'].apply(lambda wrd:[ltrs.lower() for ltrs in wrd if ltrs not in string.punctuation])
data['inputs'] = data['inputs'].apply(lambda wrd:''.join(wrd))
data
# Out:
#                                     inputs              tags
# 0                                    hello          greeting
# 1                                       hi          greeting
# 2                         nice to meet you          greeting
# 3      hi this is the pirates organisation          greeting
# 4                         any pirates here          greeting
# 5                                 hi there          greeting
# 6                                      hey          greeting
# 7                                hey there          greeting
# 8                                thank you           goodbye
# 9                                   thanks           goodbye
# 10                     thanks for the info           goodbye
# 11                                     bye           goodbye
# 12                                 bye bro           goodbye
# 13                                   adios           goodbye
# 14                                okay bye           goodbye
# 15                                 goodbye           goodbye
# 16                           see you later           goodbye
# 17                  i will catch you later           goodbye
# 18                             how are you           howami
# 19                   i am fine how are you           howami
# 20                            are you fine           howami
# 21                    how are things going           howami
# 22                everything going on okay           howami
# 23                         hows everything           howami
# 24                            who are you          whoareyou
# 25                           what are you          whoareyou
# 26                      what is your name          whoareyou
# 27                      are you a chatbot          whoareyou
# 28                    what can i call you          whoareyou
# 29                              your name          whoareyou
# 30                           are you a bot         whoareyou
# 31                     where are you from        whereareyou
# 32             which country are you from        whereareyou
# 33                      where do you live        whereareyou
# 34                      where do you live        whereareyou
# 35                which place do you live        whereareyou
# 36                   how to get recruited               join
# 37                            how to join               join
# 38                 how do i get recruited               join
# 39                  how to join strawhats               join
# 40                how do i join strawhats               join
# 41  where is the straw hat centre located   whereisthecentre
# 42        location of the straw hat centre  whereisthecentre
# 43               straw hat centre location  whereisthecentre
# 44  where can i find the straw hat centre   whereisthecentre
# 45          what are the job requirements      prerequisites
# 46            what are the pre requisites      prerequisites
# 47             what are the prerequisites      prerequisites
# 48        tell me about the prerequisites      prerequisites

# %%
#tokenize the data
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(num_words = 2000)
tokenizer.fit_on_texts(data['inputs'])
train = tokenizer.texts_to_sequences(data['inputs'])

#apply padding
from tensorflow.keras.preprocessing.sequence import pad_sequences
x_train = pad_sequences(train)

#encoding the outputs
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(data['tags'])

# %%
input_shape = x_train.shape[1]
print(input_shape)
# Out:
# 8

# %%
#define vocabulary
vocabulary = len(tokenizer.word_index)
print("Number of unique words: ",vocabulary)
output_length = le.classes_.shape[0]
print("Output Length: ",output_length)
# Out:
# Number of unique words:  73
# Output Length:  8

# %%
 #creating model
 i = Input(shape=(input_shape,))
 x = Embedding(vocabulary+1,10)(i)
 x = LSTM(10,return_sequences=True)(x)
 x = Flatten()(x)
 x = Dense(output_length,activation="softmax")(x)
 model = Model(i,x)

# %%
#compiling model
model.compile(loss="sparse_categorical_crossentropy",optimizer='adam',metrics=['accuracy'])

# %%
#training model
train = model.fit(x_train,y_train,epochs=200)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 3s 15ms/step - loss: 2.0801 - accuracy: 0.0612
# Epoch 2/200
# 2/2 [==============================] - 0s 13ms/step - loss: 2.0775 - accuracy: 0.2245
# Epoch 3/200
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0757 - accuracy: 0.2041
# Epoch 4/200
# 2/2 [==============================] - 0s 12ms/step - loss: 2.0733 - accuracy: 0.2041
# Epoch 5/200
# 2/2 [==============================] - 0s 12ms/step - loss: 2.0712 - accuracy: 0.2041
# Epoch 6/200
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0692 - accuracy: 0.2041
# Epoch 7/200
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0670 - accuracy: 0.2041
# Epoch 8/200
# 2/2 [==============================] - 0s 12ms/step - loss: 2.0645 - accuracy: 0.2041
# Epoch 9/200
# 2/2 [==============================] - 0s 12ms/step - loss: 2.0619 - accuracy: 0.2041
# Epoch 10/200
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0596 - accuracy: 0.2041
# Epoch 11/200
# 2/2 [==============================] - 0s 12ms/step - loss: 2.0567 - accuracy: 0.2041
# Epoch 12/200
# 2/2 [==============================] - 0s 14ms/step - loss: 2.0538 - accuracy: 0.2041
# Epoch 13/200
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0503 - accuracy: 0.2041
# Epoch 14/200
# 2/2 [==============================] - 0s 12ms/step - loss: 2.0470 - accuracy: 0.2041
# Epoch 15/200
# 2/2 [==============================] - 0s 15ms/step - loss: 2.0437 - accuracy: 0.2041
# Epoch 16/200
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0397 - accuracy: 0.2041
# Epoch 17/200
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0353 - accuracy: 0.2041
# Epoch 18/200
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0308 - accuracy: 0.2041
# Epoch 19/200
# 2/2 [==============================] - 0s 18ms/step - loss: 2.0258 - accuracy: 0.2041
# Epoch 20/200
# 2/2 [==============================] - 0s 13ms/step - loss: 2.0211 - accuracy: 0.2041
# Epoch 21/200
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0147 - accuracy: 0.2041
# Epoch 22/200
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0095 - accuracy: 0.2041
# Epoch 23/200
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0025 - accuracy: 0.2041
# Epoch 24/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.9965 - accuracy: 0.2041
# Epoch 25/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.9892 - accuracy: 0.2041
# Epoch 26/200
# 2/2 [==============================] - 0s 12ms/step - loss: 1.9825 - accuracy: 0.2041
# Epoch 27/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.9737 - accuracy: 0.2041
# Epoch 28/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.9654 - accuracy: 0.2041
# Epoch 29/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.9574 - accuracy: 0.2041
# Epoch 30/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.9508 - accuracy: 0.2041
# Epoch 31/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.9407 - accuracy: 0.2041
# Epoch 32/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.9346 - accuracy: 0.2041
# Epoch 33/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.9255 - accuracy: 0.2041
# Epoch 34/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.9168 - accuracy: 0.2041
# Epoch 35/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.9086 - accuracy: 0.2041
# Epoch 36/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.8996 - accuracy: 0.2245
# Epoch 37/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.8911 - accuracy: 0.2245
# Epoch 38/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.8822 - accuracy: 0.2245
# Epoch 39/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.8727 - accuracy: 0.2245
# Epoch 40/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.8626 - accuracy: 0.2245
# Epoch 41/200
# 2/2 [==============================] - 0s 12ms/step - loss: 1.8534 - accuracy: 0.2245
# Epoch 42/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.8430 - accuracy: 0.2245
# Epoch 43/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.8314 - accuracy: 0.2245
# Epoch 44/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.8205 - accuracy: 0.2245
# Epoch 45/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.8100 - accuracy: 0.2245
# Epoch 46/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.7974 - accuracy: 0.2449
# Epoch 47/200
# 2/2 [==============================] - 0s 14ms/step - loss: 1.7847 - accuracy: 0.2449
# Epoch 48/200
# 2/2 [==============================] - 0s 12ms/step - loss: 1.7723 - accuracy: 0.2653
# Epoch 49/200
# 2/2 [==============================] - 0s 14ms/step - loss: 1.7603 - accuracy: 0.2653
# Epoch 50/200
# 2/2 [==============================] - 0s 12ms/step - loss: 1.7457 - accuracy: 0.2653
# Epoch 51/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.7323 - accuracy: 0.2653
# Epoch 52/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.7185 - accuracy: 0.2857
# Epoch 53/200
# 2/2 [==============================] - 0s 12ms/step - loss: 1.7044 - accuracy: 0.2857
# Epoch 54/200
# 2/2 [==============================] - 0s 15ms/step - loss: 1.6905 - accuracy: 0.2857
# Epoch 55/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.6765 - accuracy: 0.3265
# Epoch 56/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.6604 - accuracy: 0.3265
# Epoch 57/200
# 2/2 [==============================] - 0s 12ms/step - loss: 1.6459 - accuracy: 0.3265
# Epoch 58/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.6297 - accuracy: 0.3265
# Epoch 59/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.6128 - accuracy: 0.3265
# Epoch 60/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.5964 - accuracy: 0.3469
# Epoch 61/200
# 2/2 [==============================] - 0s 12ms/step - loss: 1.5795 - accuracy: 0.3673
# Epoch 62/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.5628 - accuracy: 0.3878
# Epoch 63/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.5457 - accuracy: 0.4082
# Epoch 64/200
# 2/2 [==============================] - 0s 13ms/step - loss: 1.5276 - accuracy: 0.4490
# Epoch 65/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.5103 - accuracy: 0.4694
# Epoch 66/200
# 2/2 [==============================] - 0s 12ms/step - loss: 1.4915 - accuracy: 0.4898
# Epoch 67/200
# 2/2 [==============================] - 0s 12ms/step - loss: 1.4729 - accuracy: 0.4898
# Epoch 68/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.4555 - accuracy: 0.5306
# Epoch 69/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.4349 - accuracy: 0.5306
# Epoch 70/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.4171 - accuracy: 0.5714
# Epoch 71/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.3962 - accuracy: 0.5714
# Epoch 72/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.3786 - accuracy: 0.5714
# Epoch 73/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.3589 - accuracy: 0.5714
# Epoch 74/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.3397 - accuracy: 0.5714
# Epoch 75/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.3198 - accuracy: 0.5714
# Epoch 76/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.2994 - accuracy: 0.5918
# Epoch 77/200
# 2/2 [==============================] - 0s 13ms/step - loss: 1.2828 - accuracy: 0.5918
# Epoch 78/200
# 2/2 [==============================] - 0s 12ms/step - loss: 1.2600 - accuracy: 0.6327
# Epoch 79/200
# 2/2 [==============================] - 0s 13ms/step - loss: 1.2393 - accuracy: 0.6531
# Epoch 80/200
# 2/2 [==============================] - 0s 12ms/step - loss: 1.2199 - accuracy: 0.6939
# Epoch 81/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.2004 - accuracy: 0.7143
# Epoch 82/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.1794 - accuracy: 0.7143
# Epoch 83/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.1598 - accuracy: 0.7143
# Epoch 84/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.1387 - accuracy: 0.7143
# Epoch 85/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.1203 - accuracy: 0.7143
# Epoch 86/200
# 2/2 [==============================] - 0s 15ms/step - loss: 1.1009 - accuracy: 0.7551
# Epoch 87/200
# 2/2 [==============================] - 0s 12ms/step - loss: 1.0806 - accuracy: 0.7551
# Epoch 88/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.0614 - accuracy: 0.7551
# Epoch 89/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.0429 - accuracy: 0.7551
# Epoch 90/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.0232 - accuracy: 0.7755
# Epoch 91/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.0050 - accuracy: 0.7755
# Epoch 92/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.9863 - accuracy: 0.7959
# Epoch 93/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9682 - accuracy: 0.7959
# Epoch 94/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.9503 - accuracy: 0.7959
# Epoch 95/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.9324 - accuracy: 0.7755
# Epoch 96/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.9155 - accuracy: 0.7755
# Epoch 97/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.8985 - accuracy: 0.7755
# Epoch 98/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.8830 - accuracy: 0.7755
# Epoch 99/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.8658 - accuracy: 0.7959
# Epoch 100/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.8504 - accuracy: 0.7755
# Epoch 101/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.8351 - accuracy: 0.7755
# Epoch 102/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.8193 - accuracy: 0.8163
# Epoch 103/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.8035 - accuracy: 0.8163
# Epoch 104/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7895 - accuracy: 0.8163
# Epoch 105/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7767 - accuracy: 0.8163
# Epoch 106/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7617 - accuracy: 0.8163
# Epoch 107/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7468 - accuracy: 0.8163
# Epoch 108/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7336 - accuracy: 0.8163
# Epoch 109/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7215 - accuracy: 0.8367
# Epoch 110/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7103 - accuracy: 0.8571
# Epoch 111/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6977 - accuracy: 0.8571
# Epoch 112/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6847 - accuracy: 0.8571
# Epoch 113/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6718 - accuracy: 0.8367
# Epoch 114/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6604 - accuracy: 0.8163
# Epoch 115/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6505 - accuracy: 0.8163
# Epoch 116/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6380 - accuracy: 0.8163
# Epoch 117/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6283 - accuracy: 0.8776
# Epoch 118/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6169 - accuracy: 0.8776
# Epoch 119/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6065 - accuracy: 0.8571
# Epoch 120/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5971 - accuracy: 0.8571
# Epoch 121/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5882 - accuracy: 0.8571
# Epoch 122/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5777 - accuracy: 0.8571
# Epoch 123/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5669 - accuracy: 0.8571
# Epoch 124/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5581 - accuracy: 0.8776
# Epoch 125/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5520 - accuracy: 0.9184
# Epoch 126/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5406 - accuracy: 0.9184
# Epoch 127/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5327 - accuracy: 0.8776
# Epoch 128/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5247 - accuracy: 0.8571
# Epoch 129/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5170 - accuracy: 0.8571
# Epoch 130/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5098 - accuracy: 0.8571
# Epoch 131/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4989 - accuracy: 0.8571
# Epoch 132/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4919 - accuracy: 0.8571
# Epoch 133/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.4833 - accuracy: 0.8776
# Epoch 134/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4762 - accuracy: 0.8776
# Epoch 135/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4687 - accuracy: 0.9184
# Epoch 136/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4623 - accuracy: 0.9388
# Epoch 137/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.4551 - accuracy: 0.9388
# Epoch 138/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4484 - accuracy: 0.9592
# Epoch 139/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.4414 - accuracy: 0.9592
# Epoch 140/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4344 - accuracy: 0.9388
# Epoch 141/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4284 - accuracy: 0.9184
# Epoch 142/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4227 - accuracy: 0.9184
# Epoch 143/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4160 - accuracy: 0.8980
# Epoch 144/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4093 - accuracy: 0.9388
# Epoch 145/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4040 - accuracy: 0.9388
# Epoch 146/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3980 - accuracy: 0.9388
# Epoch 147/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3918 - accuracy: 0.9388
# Epoch 148/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3862 - accuracy: 0.9388
# Epoch 149/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3798 - accuracy: 0.9388
# Epoch 150/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3757 - accuracy: 0.9388
# Epoch 151/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3714 - accuracy: 0.9388
# Epoch 152/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3672 - accuracy: 0.9184
# Epoch 153/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3593 - accuracy: 0.9388
# Epoch 154/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3582 - accuracy: 0.9388
# Epoch 155/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3522 - accuracy: 0.9388
# Epoch 156/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3470 - accuracy: 0.9592
# Epoch 157/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3390 - accuracy: 0.9592
# Epoch 158/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.3355 - accuracy: 0.9592
# Epoch 159/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3314 - accuracy: 0.9592
# Epoch 160/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3262 - accuracy: 0.9592
# Epoch 161/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3216 - accuracy: 0.9796
# Epoch 162/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3156 - accuracy: 1.0000
# Epoch 163/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3117 - accuracy: 1.0000
# Epoch 164/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3066 - accuracy: 1.0000
# Epoch 165/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3045 - accuracy: 1.0000
# Epoch 166/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2997 - accuracy: 1.0000
# Epoch 167/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2942 - accuracy: 1.0000
# Epoch 168/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2897 - accuracy: 1.0000
# Epoch 169/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2857 - accuracy: 1.0000
# Epoch 170/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2817 - accuracy: 1.0000
# Epoch 171/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2781 - accuracy: 1.0000
# Epoch 172/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2738 - accuracy: 1.0000
# Epoch 173/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2697 - accuracy: 1.0000
# Epoch 174/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2657 - accuracy: 1.0000
# Epoch 175/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2636 - accuracy: 1.0000
# Epoch 176/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2606 - accuracy: 1.0000
# Epoch 177/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2559 - accuracy: 1.0000
# Epoch 178/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2508 - accuracy: 1.0000
# Epoch 179/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2491 - accuracy: 1.0000
# Epoch 180/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2469 - accuracy: 1.0000
# Epoch 181/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2429 - accuracy: 1.0000
# Epoch 182/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2382 - accuracy: 1.0000
# Epoch 183/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2341 - accuracy: 1.0000
# Epoch 184/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2312 - accuracy: 1.0000
# Epoch 185/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2289 - accuracy: 1.0000
# Epoch 186/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2247 - accuracy: 1.0000
# Epoch 187/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2230 - accuracy: 1.0000
# Epoch 188/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2191 - accuracy: 1.0000
# Epoch 189/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2156 - accuracy: 1.0000
# Epoch 190/200
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2128 - accuracy: 1.0000
# Epoch 191/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2114 - accuracy: 1.0000
# Epoch 192/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2064 - accuracy: 1.0000
# Epoch 193/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2035 - accuracy: 1.0000
# Epoch 194/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2010 - accuracy: 1.0000
# Epoch 195/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1988 - accuracy: 1.0000
# Epoch 196/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1956 - accuracy: 1.0000
# Epoch 197/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1926 - accuracy: 1.0000
# Epoch 198/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1898 - accuracy: 1.0000
# Epoch 199/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1875 - accuracy: 1.0000
# Epoch 200/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1868 - accuracy: 1.0000

# %% [markdown]
# MODEL ANALYSIS

# %%
#plotting model accuracy
plt.plot(train.history['accuracy'],label = 'Training Set Accuracy')
plt.plot(train.history['loss'],label = 'Training Set Loss')
plt.legend()

# %% [markdown]
# TESTING

# %%
#chatting
import random

while True:
  texts_p = []
  prediction_output = input('You: ')

  #removing punctuation and converting to lowercase
  prediction_input = [letters.lower() for letters in prediction_output if letters not in string.punctuation]
  prediction_input = ''.join(prediction_input)
  texts_p.append(prediction_input)

  #tokenizing and padding
  prediction_input = tokenizer.texts_to_sequences(texts_p)
  prediction_input = np.array(prediction_input).reshape(-1)
  prediction_input = pad_sequences([prediction_input],input_shape)

  #getting output from model
  output = model.predict(prediction_input)
  output = output.argmax()

  #finding the right tag and predicting
  response_tag = le.inverse_transform([output])[0]
  print("Going Merry: ",random.choice(responses[response_tag]))
  if response_tag == 'goodbye':
    break
# Out:
# You: hi
# 1/1 [==============================] - 0s 467ms/step
# Going Merry:  Hi Welcome to the world's largest pirate organisation - The Tech Chaos
# You: Thank you
# 1/1 [==============================] - 0s 24ms/step
# Going Merry:  Okay, have a nice day
